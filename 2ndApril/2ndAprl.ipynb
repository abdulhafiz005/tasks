# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('data.xlsx', header=None)

# %%
df.head()
# Out:
#      0
# 0  567
# 1  572
# 2  572
# 3  589
# 4  614

# %%
mean = df.mean()

# %%
std = df.std()

# %%
df=df - mean

# %%
df.mean()
# Out:
# 0    6.536993e-14
# dtype: float64

# %%
df=df/std

# %%
df.std()
# Out:
# 0    1.0
# dtype: float64

# %%
 df
# Out:
#            0
# 0  -2.377515
# 1  -2.309986
# 2  -2.309986
# 3  -2.080389
# 4  -1.742745
# ..       ...
# 75  1.350066
# 76  1.444606
# 77  1.782250
# 78  1.836273
# 79  2.079376
#
# [80 rows x 1 columns]

# %%
data2 = np.round(abs(np.random.randn(100))*100, 2)

# %%
data2
# Out:
# array([1.0672e+02, 3.4300e+00, 1.1010e+02, 1.0398e+02, 2.2630e+01,
#        4.0000e-01, 4.7380e+01, 4.8180e+01, 1.5968e+02, 5.7240e+01,
#        5.3090e+01, 6.2350e+01, 8.2680e+01, 1.9712e+02, 7.4740e+01,
#        8.2780e+01, 1.0580e+01, 3.2670e+01, 5.3310e+01, 8.7690e+01,
#        8.3600e+00, 5.9770e+01, 1.8130e+01, 1.1816e+02, 1.2255e+02,
#        4.7100e+01, 1.1666e+02, 1.9999e+02, 1.6568e+02, 8.5920e+01,
#        1.2150e+02, 6.0860e+01, 4.0360e+01, 3.3760e+01, 1.9056e+02,
#        9.9140e+01, 9.9740e+01, 4.9390e+01, 8.0600e+01, 9.3530e+01,
#        1.8936e+02, 2.2850e+01, 6.7900e+00, 1.2000e-01, 6.6540e+01,
#        9.0960e+01, 1.9052e+02, 1.2438e+02, 2.4150e+02, 6.5330e+01,
#        1.2702e+02, 5.2050e+01, 9.6270e+01, 8.1770e+01, 8.4990e+01,
#        1.2957e+02, 4.9950e+01, 6.7140e+01, 5.2510e+01, 2.2355e+02,
#        1.1008e+02, 1.0053e+02, 3.7350e+01, 6.5420e+01, 3.5560e+01,
#        6.2910e+01, 9.6200e+00, 2.5070e+01, 2.2428e+02, 8.5990e+01,
# ...

# %%
random = np.round(np.random.rand(1, 1000)*100, 2)

# %%
random
# Out:
# array([[8.254e+01, 9.487e+01, 6.416e+01, 1.811e+01, 3.455e+01, 5.429e+01,
#         1.034e+01, 3.302e+01, 5.298e+01, 4.783e+01, 7.529e+01, 4.759e+01,
#         9.739e+01, 7.382e+01, 1.035e+01, 7.546e+01, 8.300e+00, 9.305e+01,
#         5.779e+01, 7.731e+01, 5.745e+01, 3.574e+01, 6.363e+01, 1.281e+01,
#         2.373e+01, 5.668e+01, 4.415e+01, 2.099e+01, 4.627e+01, 7.903e+01,
#         3.945e+01, 8.706e+01, 9.025e+01, 4.406e+01, 4.881e+01, 8.348e+01,
#         7.964e+01, 4.606e+01, 8.095e+01, 5.429e+01, 2.441e+01, 4.189e+01,
#         9.486e+01, 5.417e+01, 1.623e+01, 8.118e+01, 2.541e+01, 3.108e+01,
#         6.877e+01, 6.803e+01, 7.413e+01, 8.886e+01, 8.337e+01, 9.811e+01,
#         4.386e+01, 5.087e+01, 8.251e+01, 9.660e+00, 2.379e+01, 2.733e+01,
#         4.853e+01, 1.048e+01, 4.293e+01, 3.786e+01, 5.647e+01, 8.509e+01,
#         7.300e+01, 4.667e+01, 7.900e+00, 7.379e+01, 2.630e+01, 9.018e+01,
#         4.637e+01, 7.861e+01, 5.071e+01, 7.523e+01, 2.424e+01, 1.442e+01,
# ...

# %%
random = pd.
s1 = random.sample(n = 25)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-c70b843ae3b6> in <module>
# ----> 1 s1 = random.sample(n = 25)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sample'
